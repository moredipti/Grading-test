# %% [markdown]
# Question no 1
# ANSWERS

# %% [markdown]
# QUE 1) Answer = 1
#       python code is both compiled and interpreted.

# %% [markdown]
# QUE 2) Answer = 2
#       It confuses the interpreter

# %% [markdown]
# QUE 3) Answer = 2
#        You dont have covid,Test says you have.

# %% [markdown]
# QUE 4) Answer = 2
#        84

# %% [markdown]
# QUE 5) Answer = 1
#        *

# %% [markdown]
# Question no 2
# ANSWERS

# %%
#QUE 1) Answer =
    
name=input("enter the string")
a=list(name)
len(a)


for i in range(0,len(a),2):
    print(a[i])
# Out:
# enter the stringpra
# p
# a

# %%
#QUE 2) Answer = 

n=[12,75,150,180,145,525,50]

for i in n:
    for j in range(i+1):
        if i/5:
            print("The given number is divisible by 5",i,end="\n")
            
for i in n: 
        print(i)
        
        for i in n:
            if i>150:
                 print("the given number is greater than 150",i,end="\n")
            print(i)
        
        for i in n:
            if i>500:
                print("the given number is greater than 500",i,end="\n")
            print(i)
            break
# Out:
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 12
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# The given number is divisible by 5 75
# ...

# %%
#QUE 3)

numbers = [1,2,3,4,5,6,7]
numbers = [n**2 for n in range(8)]
numbers
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49]

# %%
#QUE 4) Answer

days=["sun","mon","tue","wed","thus","fri","sat"]
temp=[30.5,32.6,31.8,33.4,29.8,30.2,29.9]
di={i:j for i,j in zip(days,temp)}
di
# Out:
# {'sun': 30.5,
#  'mon': 32.6,
#  'tue': 31.8,
#  'wed': 33.4,
#  'thus': 29.8,
#  'fri': 30.2,
#  'sat': 29.9}

# %% [raw]
# #QUE 5) Answer
#
# Let K be the event that both are kings
# P(K) = 4c2/ 52c2  = 1/221
#    = 1/221

# %% [markdown]
# #QUE 6) Answer
#
# Method overriding
# object oriented programming is this some class define behaviour method inheritance

# %%
#method overriding

class Vehicle{  
  void run(){System.out.println("Vehicle is running");}  
}  
//Creating a child class  
class Bike extends Vehicle{  
  public static void main(String args[]){  
  //creating an instance of child class  
  Bike obj = new Bike();  
  //calling the method with child class instance  
  obj.run();  
  }  
}
# Out:
#   Cell In[24], line 3
#     class Vehicle{
#                  ^
# SyntaxError: invalid syntax

# %%
# QUE 7) ANSWER

cheak=int(input('enter the number'))
if cheak==0 and cheak%7==0:
    print(f"your number{cheak}is divisible by 5 and 7 both")
else:
        print(f"your number{cheak}is not satisfy the condition")
# Out:
# enter the number35
# your number35is not satisfy the condition

# %%
#QUE 8) Answer

Types of distribution


1)Uniform Distribution

2)Normal Distribution

3)Binomial distribution
            
4)Bernoulli Distribution

5)Poisson Distribution
    
6)Exponential Distribution

# %% [markdown]
# #QUE 9) Answer
#
# Central limit theorem
#
# In probability theorem the central limit therom states that the distribution of the sample variable approximates
# the normal distribution(i.e the bell curve).
# As the sample size becomes larger,assuming that all samples are identical in size, and regardless of populations actual distribution shape.
# The data must adher to the randomization rule it must be sample at random.the sample must be unrealated to one another.
# one sample should not impact to other.
# When taking samples without replacement the sample size should not exced 10% of population

# %%
a=8
b=4
print(a+b)       #addition
print(a-b)       #substraction
print(a*b)       #multiplication

# %% [markdown]
# QUESTION NO 3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Dipti\Downloads\supermarket_sales - Sheet1.csv")

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
data.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6

# %%
#ANS 1)

data.drop("Invoice ID",axis = 1,inplace=True)
data.drop("Date",axis = 1,inplace=True)
data.drop("Time",axis = 1,inplace=True)

# %%
# Ans 3)

sns.barplot(y="Product line",x="gross income",data=data,palette='PuRd',ci=None)
# Out:
# C:\Users\Dipti\AppData\Local\Temp\ipykernel_14116\3348326592.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(y="Product line",x="gross income",data=data,palette='PuRd',ci=None)
# <Axes: xlabel='gross income', ylabel='Product line'>

# %%
# Ans 4)

plt.boxplot(x=data['Quantity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x195e9e0dcf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x195e9e0e230>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x195e9e0da50>],
#  'medians': [<matplotlib.lines.Line2D at 0x195e9e0e770>],
#  'fliers': [<matplotlib.lines.Line2D at 0x195e9e0ea10>],
#  'means': []}

# %%
# Ans 5)
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True,cmap='RdYlGn')
# Out:
# C:\Users\Dipti\AppData\Local\Temp\ipykernel_14116\1823226618.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True,cmap='RdYlGn')
# <Axes: >
